# %% [markdown]
# #### Monday, June 24, 2024
#
# <img src="../images/Figure_2.1.png" alt="Figure 2.1" width="400">
#
# I asked Jack to send this image to Chat GPT, and he asked ..."Please write the code for this".
#
# He go back this, and sent it to me ... amazing!

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Function definition
def f(x1, x2):
    return np.sin(2 * np.pi * x1) * np.sin(2 * np.pi * x2)

# Generate data for the 3D plot
x1 = np.linspace(0, 1, 100)
x2 = np.linspace(0, 1, 100)
x1, x2 = np.meshgrid(x1, x2)
y = f(x1, x2)

# 3D plot
fig = plt.figure(figsize=(18, 6))
ax = fig.add_subplot(131, projection='3d')
ax.plot_surface(x1, x2, y, cmap='viridis')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$y$')
ax.set_title('3D plot of $y(x_1, x_2) = \sin(2\pi x_1) \sin(2\pi x_2)$')

# Generate data for 2D plots
n_samples = 100
x1_samples = np.random.uniform(0, 1, n_samples)
x2_samples = np.random.uniform(0, 1, n_samples)
y_samples = f(x1_samples, x2_samples) + np.random.normal(0, 0.1, n_samples)  # adding Gaussian noise

# Plot when x2 is unobserved
ax = fig.add_subplot(132)
ax.scatter(x1_samples, y_samples, color='red')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$y$')
ax.set_title('Plot with high noise ($x_2$ unobserved)')

# Plot when x2 is fixed to pi/2
x2_fixed = np.pi / 2
y_fixed = f(x1_samples, x2_fixed) + np.random.normal(0, 0.1, n_samples)

ax = fig.add_subplot(133)
ax.scatter(x1_samples, y_fixed, color='red')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$y$')
ax.set_title('Plot with lower noise ($x_2$ fixed to $\pi/2$)')

plt.tight_layout()
plt.show()

# %% [markdown]
# And here is what I got back from [Claude](https://claude.ai/chat/90ba0b70-9c02-418e-8be2-0d51482328d2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Set random seed for reproducibility
np.random.seed(42)

# Define the function
def y(x1, x2):
    return np.sin(2 * np.pi * x1) * np.sin(2 * np.pi * x2)

# Create figure and subplots
fig = plt.figure(figsize=(15, 5))

# (a) 3D plot of the function
ax1 = fig.add_subplot(131, projection='3d')
x1 = np.linspace(0, 1, 100)
x2 = np.linspace(0, 1, 100)
X1, X2 = np.meshgrid(x1, x2)
Y = y(X1, X2)

ax1.plot_surface(X1, X2, Y, cmap='coolwarm', alpha=0.8)
ax1.set_xlabel('$x_1$')
ax1.set_ylabel('$x_2$')
ax1.set_zlabel('$y$')
ax1.set_title('(a)')

# (b) Plot with high noise and unobserved x2
ax2 = fig.add_subplot(132)
x1_b = np.random.rand(100)
x2_b = np.random.rand(100)
y_b = y(x1_b, x2_b) + np.random.normal(0, 0.3, 100)

ax2.scatter(x1_b, y_b, color='red', alpha=0.7)
ax2.set_xlabel('$x_1$')
ax2.set_ylabel('$y$')
ax2.set_title('(b)')

# (c) Plot with fixed x2 and lower noise
ax3 = fig.add_subplot(133)
x1_c = np.random.rand(100)
x2_c = 0.5 * np.ones(100)
y_c = y(x1_c, x2_c) + np.random.normal(0, 0.1, 100)

ax3.scatter(x1_c, y_c, color='red', alpha=0.7)
ax3.set_xlabel('$x_1$')
ax3.set_ylabel('$y$')
ax3.set_title('(c)')

plt.tight_layout()
plt.show()
